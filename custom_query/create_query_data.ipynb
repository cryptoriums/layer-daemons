# %%
pip install eth_abi
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install web3
# Out:
# ...
#   Using cached web3-7.13.0-py3-none-any.whl (1.4 MB)
# ...
#   Using cached eth_account-0.13.7-py3-none-any.whl (587 kB)
# ...
#   Using cached hexbytes-1.3.1-py3-none-any.whl (5.1 kB)
# ...
#   Using cached pyunormalize-16.0.0-py3-none-any.whl (49 kB)
# ...
#   Using cached websockets-15.0.1-cp39-cp39-macosx_11_0_arm64.whl (173 kB)
# ...
#   Using cached aiohttp-3.12.15-cp39-cp39-macosx_11_0_arm64.whl (469 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 3.8 MB/s eta 0:00:00
# ...
#   Using cached async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# ...
#   Using cached yarl-1.20.1-cp39-cp39-macosx_11_0_arm64.whl (89 kB)
# ...
#   Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# ...
#   Using cached frozenlist-1.7.0-cp39-cp39-macosx_11_0_arm64.whl (47 kB)
# ...
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# ...
#   Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# ...

# %%
from eth_abi import encode, decode
from web3 import Web3
da = encode(['string', 'string'], ["susde", "usd"])
qdata = encode(["string", "bytes"], ["SpotPrice", da])
print(qdata.hex())
Web3.keccak(qdata).hex()
# Out:
# ...
# '0bc2d41117ae8779da7623ee76a109c88b84b9bf4d9b404524df04f7d0ca4ca7'

# %%
int("0000000000000000000000000000000000000000000000ccf1f2c0ae82890000", 16) / 1e18
# Out:
# 3780.5699999999997

# %%
decode(['bytes'], bytes.fromhex(""))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 decode(['bytes'], "")
#
# File ~/.pyenv/versions/3.9.21/lib/python3.9/site-packages/eth_abi/codec.py:153, in ABIDecoder.decode(self, types, data, strict)
#     151 # validate decode types and data
#     152 validate_list_like_param(types, "types")
# --> 153 validate_bytes_param(data, "data")
#     155 decoders = [
#     156     self._registry.get_decoder(type_str, strict=strict) for type_str in types
#     157 ]
#     159 decoder = TupleDecoder(decoders=decoders)
#
# ...
